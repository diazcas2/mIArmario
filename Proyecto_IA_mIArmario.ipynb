# %% [markdown]
# <a href="https://colab.research.google.com/github/diazcas2/mIArmario/blob/main/Proyecto_IA_mIArmario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CÓDIGO DEL MAIN:**
